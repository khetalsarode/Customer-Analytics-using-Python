# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
train=pd.read_csv("C:\\Users\\aspire 3\\Desktop\\Term 3 Project\\train.csv")

# %%
train.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
newdata = train.rename(columns = {"Reached.on.Time_Y.N":"Reached_on_Time_Y_N"})

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Prior_purchases", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('Prior_puchase and Reached on-time')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Customer_rating", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('Customer Rating and Reached on-time')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Product_importance", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('Product importance and Reached on-time')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Gender", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('gender and Reached on-time')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Warehouse_block", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N",order = newdata['Warehouse_block'].value_counts().index);
plt.title('warehouse block and Reached on-time')
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot as plt
sb.countplot(x = "Mode_of_Shipment", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('Mode of shipment and Reached on-time')
plt.show()

# %%
sb.countplot(x = "Customer_care_calls", data = newdata, palette = "plasma",hue="Reached_on_Time_Y_N");
plt.title('Customer care calls and Reached on-time')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(newdata['Cost_of_the_Product'], bins = 20)
plt.title('Histogram of Cost Of Product')
plt.xlabel('Cost_of_the_Product')
# Out:
# Text(0.5,0,'Cost_of_the_Product')
